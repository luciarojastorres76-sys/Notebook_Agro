# %% [markdown]
# <a href="https://colab.research.google.com/github/luciarojastorres76-sys/Notebook_Agro/blob/main/Rendimiento_Extracci%C3%B3n_de_Aceite_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
# Una planta procesadora de palma de aceite necesita **calcular el Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float) . (pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L. (r)
#
# $$pa =lt * 0.92$$
#
# $$r=(pa/pr) * 100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA:Solicitar el nombre del lote de producción (Tipo string).
# Solicitar el peso de los racimos en kg (Tipo float) . (pr)
# Solicitar los litros de aceite obtenidos (Tipo float). (lt)
nombre = input("Ingrese el nombre del lote: ")
pr = float(input("ingrese el peso de los racimos en kg:  "))
lt= float(input("ingrese la cantidad de aceite crudo obtenido en litros: "))

# PROCESO: Calcular peso el aceite (Pa) y el rendimiento (r)
pa= lt * 0.92
r= (pa/pr)*100

#SALIDA: in formar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote: el perico
# ingrese el peso de los racimos en kg:  100
# ingrese la cantidad de aceite crudo obtenido en litros: 200
# El rendimiento del lote el perico es del 184.0 %

# %% [markdown]
# ```markdown
# Aquí está la explicación línea por línea del código para el cálculo del rendimiento en la extracción de aceite:
#
# ```python
# # ENTRADA:Solicitar el nombre del lote de producción (Tipo string).
# # Solicitar el peso de los racimos en kg (Tipo float) . (pr)
# # Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# ```
# Estas líneas son comentarios que describen los datos de entrada que el programa solicitará al usuario. Indican qué tipo de dato se espera (string, float) y la variable que se utilizará para almacenarlos (`pr` para peso de racimos, `lt` para litros de aceite).
#
# ```python
# nombre = input("Ingrese el nombre del lote: ")
# ```
# Esta línea solicita al usuario que ingrese el nombre del lote de producción. La función `input()` muestra el mensaje entre comillas al usuario y espera su entrada. La respuesta del usuario, que es un texto (string), se almacena en la variable `nombre`.
#
# ```python
# pr = float(input("ingrese el peso de los racimos en kg:  "))
# ```
# Aquí se pide al usuario que ingrese el peso de los racimos en kilogramos. Similar a la línea anterior, `input()` obtiene el texto del usuario. La función `float()` convierte ese texto a un número decimal (punto flotante), ya que el peso puede no ser un número entero. Este valor se guarda en la variable `pr`.
#
# ```python
# lt= float(input("ingrese la cantidad de aceite crudo obtenido en litros: "))
# ```
# Esta línea es similar a la anterior, pero solicita la cantidad de aceite crudo obtenida en litros. La entrada del usuario se convierte a un número decimal con `float()` y se almacena en la variable `lt`.
#
# ```python
# # PROCESO: Calcular peso el aceite (Pa) y el rendimiento (r)
# ```
# Este comentario indica que las siguientes líneas de código realizarán los cálculos necesarios para obtener el rendimiento.
#
# ```python
# pa= lt * 0.92
# ```
# En esta línea, se calcula el peso del aceite (`pa`) multiplicando la cantidad de aceite en litros (`lt`) por su densidad aproximada (0.92 kg/L). El resultado es el peso del aceite en kilogramos.
#
# ```python
# r= (pa/pr)*100
# ```
# Aquí se calcula el Índice de Rendimiento de Extracción (`r`). Se divide el peso del aceite (`pa`) por el peso de los racimos (`pr`) y el resultado se multiplica por 100 para expresarlo como un porcentaje.
#
# ```python
# #SALIDA: in formar el rendimiento del lote
# ```
# Este comentario señala que la siguiente línea de código mostrará el resultado al usuario.
#
# ```python
# print("El rendimiento del lote", nombre, "es del", r, "%")
# ```
# Finalmente, esta línea imprime el resultado en la consola. Utiliza la función `print()` para mostrar una cadena de texto que combina el nombre del lote (`nombre`), el rendimiento calculado (`r`) y el símbolo de porcentaje (`%`), creando un mensaje claro y comprensible para el usuario.
# ```
